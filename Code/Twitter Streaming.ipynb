# %%
import tweepy
from tweepy import OAuthHandler
con_key = 'xrFibltAhX0JPhrnrSJz3QcLR'
con_sec = 'zIbVS37OZmFKCoEsoPIalsR4MG1hSZStknrkdQJxnBhPuSi9zT'
acc_tok = '968298708721741824-7qTav3AG5eG5QOXgPQOzAhrrK8bnlW1'
acc_sec = 'ij4sptlcUgeBaNZuHfcha7ZWZHMVnWDrnwg7ZFO8FjKMo'

# %%
auth = OAuthHandler(con_key, con_sec)
auth.set_access_token(acc_tok, acc_sec)

api = tweepy.API(auth)

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

class MyListener(StreamListener):
    
    def on_data(self, data):
        try:
            with open('Emoji.json', 'a') as f:
                f.write(data)
                return True
            
        except BaseException as e:
            print('Error on_data : %s' % str(e))
        return True
    
    def on_error(self, status):
        print(status)
        return True
    
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track = emoji_list, languages=['en'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-5d7b76d497cb> in <module>()
#      19
#      20 twitter_stream = Stream(auth, MyListener())
# ---> 21 twitter_stream.filter(track = emoji_list, languages=['en'])
#
# /Users/hsnu130427/anaconda2/lib/python2.7/site-packages/tweepy-3.6.0-py2.7.egg/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /Users/hsnu130427/anaconda2/lib/python2.7/site-packages/tweepy-3.6.0-py2.7.egg/tweepy/streaming.pyc in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
# ...

# %%
import re


class Emoticons:
    POSITIVE = ["*O", "*-*", "*O*", "*o*", "* *",
                ":P", ":D", ":d", ":p",
                ";P", ";D", ";d", ";p",
                ":-)", ";-)", ":=)", ";=)",
                ":<)", ":>)", ";>)", ";=)",
                "=}", ":)", "(:;)",
                "(;", ":}", "{:", ";}",
                "{;:]",
                "[;", ":')", ";')", ":-3",
                "{;", ":]",
                ";-3", ":-x", ";-x", ":-X",
                ";-X", ":-}", ";-=}", ":-]",
                ";-]", ":-.)",
                "^_^", "^-^"]

    NEGATIVE = [":(", ";(", ":'(",
                "=(", "={", "):", ");",
                ")':", ")';", ")=", "}=",
                ";-{{", ";-{", ":-{{", ":-{",
                ":-(", ";-(",
                ":,)", ":'{",
                "[:", ";]"
                ]


class ParseTweet(object):
    # compile once on import
    regexp = {"RT": "^RT", "MT": r"^MT", "ALNUM": r"(@[a-zA-Z0-9_]+)",
              "HASHTAG": r"(#[\w\d]+)", "URL": r"([https://|http://]?[a-zA-Z\d\/]+[\.]+[a-zA-Z\d\/\.]+)",
              "SPACES": r"\s+"}
    regexp = dict((key, re.compile(value)) for key, value in regexp.items())

    def __init__(self, timeline_owner, tweet):
        """ timeline_owner : twitter handle of user account. tweet - 140 chars from feed; object does all computation on construction
            properties:
            RT, MT - boolean
            URLs - list of URL
            Hashtags - list of tags
        """
        self.Owner = timeline_owner
        self.tweet = tweet
        self.UserHandles = ParseTweet.getUserHandles(tweet)
        self.Hashtags = ParseTweet.getHashtags(tweet)
        self.URLs = ParseTweet.getURLs(tweet)
        self.RT = ParseTweet.getAttributeRT(tweet)
        self.MT = ParseTweet.getAttributeMT(tweet)
        self.Emoticon = ParseTweet.getAttributeEmoticon(tweet)

        # additional intelligence
        if (self.RT and len(self.UserHandles) > 0):  # change the owner of tweet?
            self.Owner = self.UserHandles[0]
        return

    def __str__(self):
        """ for display method """
        return "owner %s, urls: %d, hashtags %d, user_handles %d, len_tweet %d, RT = %s, MT = %s" % \
               (self.Owner, len(self.URLs), len(self.Hashtags), len(self.UserHandles), len(self.tweet), self.RT, self.MT)

    @staticmethod
    def getAttributeEmoticon(tweet):
        """ see if tweet is contains any emoticons, +ve, -ve or neutral """
        emoji = list()
        for tok in re.split(ParseTweet.regexp["SPACES"], tweet.strip()):
            if tok in Emoticons.POSITIVE:
                emoji.append(tok)
                continue
            if tok in Emoticons.NEGATIVE:
                emoji.append(tok)
        return emoji

# %%
emoji_dict = {
    'Happy':[u"\U0001F601",u"\U0001F602",u"\U0001F923",u"\U0001F603",u"\U0001F604",u"\U0001F61C"
            ,u"\U0001F609",u"\U0001F606",u"\U0001F60A",u"\U0001F60B",u"\U0001F60D",u"\U0001F618"
            ,u"\U0001F617",u"\U0001F917",u"\U0001F60F",u"\U0001F60C",u"\U0001F61C",u"\U0001F643"
            ,u"\U0001F47B",u"\U0001F608",u"\U0001F913",u"\U0001F62C",u"\U0001F642",u"\U0001F917",u"\U0001F61A",u"\U0001F619",u"\U0001F61B",u"\U0001F61D"
            ,u"\U0001F63A",u"\U0001F638",u"\U0001F639",u"\U0001F63B",u"\U0001F63C",u"\U0001F63D",],
    'Sad':[u"\U0001F63F",u"\U0001F622",u"\U0001F61F",u"\U00012639",u"\U0001F641",u"\U0001F61E",],
    'Angry':[u"\U0001F63E",u"\U0001F47F",u"\U0001F621",u"\U0001F620",u"\U0001F92C",u"\U0001F624",],
    'Thinking':[u"\U0001F914",u"\U0001F928"],
    'Astonishing':[u"\U0001F640",u"\U0001F633",u"\U0001F631",u"\U0001F628",u"\U0001F627",u"\U0001F626",u"\U0001F62E",u"\U0001F62F",u"\U0001F632",],
    'Sick':[u"\U0001F927",u"\U0001F92E",u"\U0001F637",u"\U0001F912",u"\U0001F915",u"\U0001F922",],
    'neutral':[u"\U0001F610",u"\U0001F611",u"\U0001F636"],
    'Confused':[u"\U0001F623",u"\U0001F625",],
    'Sleepy':[u"\U0001F62A",u"\U0001F634",],
    'Unwanted':[u"\U0001F630",u"\U0001F629",u"\U0001F616",u"\U0001F62B",u"\U0001F613",u"\U0001F614",u"\U0001F615",],
    'Hungry':[u"\U0001F924",],
    'Money':[u"\U0001F911",],
    'Cry':[u"\U0001F62D",],
    'others':[u"\U0001F4A9",u"\U0001F635",u"\U0001F910",u"\U0001F612",u"\U0001F92A",]
}

# %%
emoji_dict
# Out:
# {'Angry': [],
#  'Astonishing': [],
#  'Happy': [u'\U0001f601',
#   u'\U0001f602',
#   u'\U0001f923',
#   u'\U0001f603',
#   u'\U0001f604',
#   u'\U0001f61c',
#   u'\U0001f609',
#   u'\U0001f606',
#   u'\U0001f60a',
#   u'\U0001f60b',
#   u'\U0001f60d',
#   u'\U0001f618',
#   u'\U0001f642',
#   u'\U0001f917',
#   u'\U0001f61a',
#   u'\U0001f619',
#   u'\U0001f61b',
#   u'\U0001f61d'],
#  'Sad': [],
#  'Sick': [],
#  'Thinking': [u'\U0001f914', u'\U0001f928']}

# %%
import bs4
from urllib import urlopen 
from bs4 import BeautifulSoup 

url = 'https://unicode.org/emoji/charts/full-emoji-list.html'
uClient = urlopen(url)
page_html = uClient.read()
page_soup = BeautifulSoup(page_html, 'html.parser')

# %%
td_tags = page_soup.find_all('td', class_='code')
emoji_list = []

for tag in td_tags:
    text = tag.string
    if text.startswith('U+1F6') and len(text) < 8:
        emoji_uni = tag.string#.encode('unicode-escape')
        #emoji_uni = '\U0001' + emoji_uni[3:]
        #print(unicode(emoji_uni[1:]))
        #emoji_list.append('\U0001' + emoji_uni[3:])
        emoji_list.append(unicode(emoji_uni))

#unicode!!!!!!!

# %%
emoji_list
# Out:
# [u'U+1F600',
#  u'U+1F601',
#  u'U+1F602',
#  u'U+1F603',
#  u'U+1F604',
#  u'U+1F605',
#  u'U+1F606',
#  u'U+1F609',
#  u'U+1F60A',
#  u'U+1F60B',
#  u'U+1F60E',
#  u'U+1F60D',
#  u'U+1F618',
#  u'U+1F617',
#  u'U+1F619',
#  u'U+1F61A',
#  u'U+1F642',
#  u'U+1F610',
#  u'U+1F611',
#  u'U+1F636',
#  u'U+1F644',
#  u'U+1F60F',
#  u'U+1F623',
#  u'U+1F625',
#  u'U+1F62E',
#  u'U+1F62F',
#  u'U+1F62A',
#  u'U+1F62B',
#  u'U+1F634',
#  u'U+1F60C',
#  u'U+1F61B',
#  u'U+1F61C',
#  u'U+1F61D',
#  u'U+1F612',
#  u'U+1F613',
#  u'U+1F614',
#  u'U+1F615',
#  u'U+1F643',
#  u'U+1F632',
#  u'U+1F641',
#  u'U+1F616',
#  u'U+1F61E',
#  u'U+1F61F',
#  u'U+1F624',
#  u'U+1F622',
#  u'U+1F62D',
#  u'U+1F626',
#  u'U+1F627',
#  u'U+1F628',
#  u'U+1F629',
#  u'U+1F62C',
#  u'U+1F630',
#  u'U+1F631',
#  u'U+1F633',
#  u'U+1F635',
#  u'U+1F621',
#  u'U+1F620',
#  u'U+1F637',
#  u'U+1F607',
#  u'U+1F608',
#  u'U+1F63A',
#  u'U+1F638',
#  u'U+1F639',
#  u'U+1F63B',
#  u'U+1F63C',
#  u'U+1F63D',
# ...

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

class MyListener(StreamListener):
    
    def on_data(self, data):
        try:
            with open('Emoji.json', 'a') as f:
                f.write(data)
                return True
            
        except BaseException as e:
            print('Error on_data : %s' % str(e))
        return True
    
    def on_error(self, status):
        print(status)
        return True
    
twitter_stream = Stream(auth, MyListener())
#there's a limit of length of track list which is 400.
twitter_stream.filter(track = emoji_list, languages=['en'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d227b0262667> in <module>()
#      19
#      20 twitter_stream = Stream(auth, MyListener())
# ---> 21 twitter_stream.filter(track = EMOJI_UNICODE.values()[:399], languages=['en'])
#
# /Users/hsnu130427/anaconda2/lib/python2.7/site-packages/tweepy-3.6.0-py2.7.egg/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /Users/hsnu130427/anaconda2/lib/python2.7/site-packages/tweepy-3.6.0-py2.7.egg/tweepy/streaming.pyc in _start(self, async)
#     362             self._thread.start()
#     363         else:
# ...

# %%
emoji_dict.values()

emoji_list = [emoji for uni in emoji_dict.values() for emoji in uni]

# %%
emoji_list
# Out:
# [u'\U0001f914',
#  u'\U0001f928',
#  u'\U0001f47f',
#  u'\U0001f621',
#  u'\U0001f620',
#  u'\U0001f92c',
#  u'\U0001f624',
#  u'\U0001f62d',
#  u'\U0001f924',
#  u'\U0001f633',
#  u'\U0001f631',
#  u'\U0001f628',
#  u'\U0001f627',
#  u'\U0001f626',
#  u'\U0001f62e',
#  u'\U0001f62f',
#  u'\U0001f632',
#  u'\U0001f610',
#  u'\U0001f611',
#  u'\U0001f636',
#  u'\U0001f927',
#  u'\U0001f92e',
#  u'\U0001f637',
#  u'\U0001f912',
#  u'\U0001f915',
#  u'\U0001f922',
#  u'\U0001f4a9',
#  u'\U0001f635',
#  u'\U0001f910',
#  u'\U0001f612',
#  u'\U0001f92a',
#  u'\U0001f601',
#  u'\U0001f602',
#  u'\U0001f923',
#  u'\U0001f603',
#  u'\U0001f604',
#  u'\U0001f61c',
#  u'\U0001f609',
#  u'\U0001f606',
#  u'\U0001f60a',
#  u'\U0001f60b',
#  u'\U0001f60d',
#  u'\U0001f618',
#  u'\U0001f617',
#  u'\U0001f917',
#  u'\U0001f60f',
#  u'\U0001f60c',
#  u'\U0001f61c',
#  u'\U0001f643',
#  u'\U0001f47b',
#  u'\U0001f608',
#  u'\U0001f913',
#  u'\U0001f62c',
#  u'\U0001f642',
#  u'\U0001f917',
# ...
